# %%
import pdfkit
import os
for filename in os.listdir(os.getcwd()):
    if filename.endswith('.html'):
        with open(os.path.join(os.getcwd(), filename), 'r') as f:
            pdfkit.from_file(f, 'final/' + filename[:-5] + '.pdf')
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Loading page (1/2)
# Printing pages (2/2)
# Done
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Loading page (1/2)
# Printing pages (2/2)
# Done
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Loading page (1/2)
# Printing pages (2/2)
# Done
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Loading page (1/2)
# Printing pages (2/2)
# Done
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Loading page (1/2)
# Printing pages (2/2)
# Done
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# Loading page (1/2)
# Printing pages (2/2)
# Done
# libpng warning: iCCP: known incorrect sRGB profile
# ...
